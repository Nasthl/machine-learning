# %% [markdown]
# <a href="https://colab.research.google.com/github/Nasthl/macnine-learning-/blob/main/%5BCOLAB%5D_Copy_of_puste_Zadania_Konwolucyjne_sieci_neuronowe_1d_i_2d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Zadanie MNIST 1:
#
# Stwórz sieć konwolucyjną z wykorzystaniem biblioteki Keras do rozpoznawania ręcznie pisanych cyfr ze zbioru MNIST. Zbiór MNIST to popularny zbiór danych zawierający obrazy cyfr od 0 do 9. Zbiór składa się z 60 000 przykładów treningowych i 10 000 przykładów testowych. Twoim zadaniem jest stworzenie modelu sieci konwolucyjnej, który będzie w stanie z dużą dokładnością rozpoznawać cyfry ze zbioru testowego.
#
# Wskazówki:
#
# * Wykorzystaj bibliotekę Keras do budowy sieci konwolucyjnej
# * Zbuduj sieć neuronową z warstwami konwolucyjnymi i warstwami w pełni połączonymi
# * Przetestuj różne architektury sieci i wybierz optymalną
# * Skaluj dane wejściowe tak, aby wartości pikseli znajdowały się w zakresie od 0 do 1
# * Przygotuj dane treningowe i testowe, a następnie naucz model na zbiorze treningowym
# * Wybierz odpowiednią funkcję straty i metrykę oceny jakości modelu
# * Zweryfikuj skuteczność modelu na zbiorze testowym

# %%
import numpy as np
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.optimizers import SGD

# wczytanie danych
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# skalowanie danych
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# konwersja etykiet na wektory one-hot
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# dodanie kanału kolorów
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)


model=Sequential()
model.add(Conv2D(16,kernel_size=(3,3),activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=SGD(learning_rate=0.01), metrics=['accuracy'])

model.fit(X_train,y_train,batch_size=32, epochs=1,verbose=1)

model.evaluate(X_test,y_test,verbose=1)
# Out:
# ...
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1904 - accuracy: 0.9467
# [0.1904182881116867, 0.9466999769210815]

# %% [markdown]
# ### Zadanie 2 CIFAR10:
#
# Stwórz sieć neuronową z wykorzystaniem biblioteki Keras do rozpoznawania obrazków ze zbior CIFAR10.
# Zbiór CIFAR-10 to popularny zbiór danych do uczenia maszynowego, składający się z 60000 kolorowych obrazów o wymiarach 32x32 pikseli, podzielonych na 10 klas, z których każda reprezentuje różne rodzaje obiektów.
#
# Klasy w zbiorze CIFAR-10 to:
#
# ```samoloty, samochody, ptaki, koty, jelenie, psy, żaby,konie,statki,ciężarówki```
#
#
# Zbiór CIFAR-10 jest często używany do uczenia i testowania algorytmów uczenia maszynowego, zwłaszcza w dziedzinie rozpoznawania obrazów. Ze względu na swoją rozmiar i złożoność, jest on trudniejszy do nauczenia niż prostsze zbiory danych, takie jak MNIST.
#
# Zbiór CIFAR-10 został opracowany przez Krizhevsky, Hinton i innych w 2009 roku, a od tego czasu stał się popularnym benchmarkiem w dziedzinie rozpoznawania obrazów i uczenia maszynowego.
#
# Zbiór składa się z 60 000 przykładów treningowych i 10 000 przykładów testowych. Twoim zadaniem jest stworzenie modelu sieci neuronowej, który będzie w stanie z dużą dokładnością rozpoznawać cyfry ze zbioru testowego.
#
# Wskazówki:
#
# * Wykorzystaj bibliotekę Keras do budowy sieci neuronowej.
# * Zbuduj sieć neuronową z warstwami konwolucyjnymi i warstwami w pełni połączonymi.
# * Przetestuj różne architektury sieci i wybierz optymalną.
# * Skaluj dane wejściowe tak, aby wartości pikseli znajdowały się w zakresie od 0 do 1.
# * Przygotuj dane treningowe i testowe, a następnie naucz model na zbiorze treningowym.
# * Wybierz odpowiednią funkcję straty i metrykę oceny jakości modelu.
# * Zweryfikuj skuteczność modelu na zbiorze testowym.
#
# Podpowiedź: Input shape do modelu: ```input_shape=(32, 32, 3)))```

# %% [markdown]
# ### Wczytanie zbioru CIFAR10

# %%
from keras.datasets import cifar10
# example of loading the cifar10 dataset
from matplotlib import pyplot

# load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (X_test.shape, y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(X_train[i])
# show the figure
pyplot.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
from keras.utils import to_categorical
# one hot encode target values

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.optimizers import Adam

# %%
X_train=X_train/255
X_test=X_test/255

X_train[0]
# Out:
# array([[[0.23137255, 0.24313725, 0.24705882],
#         [0.16862745, 0.18039216, 0.17647059],
#         [0.19607843, 0.18823529, 0.16862745],
#         ...,
#         [0.61960784, 0.51764706, 0.42352941],
#         [0.59607843, 0.49019608, 0.4       ],
#         [0.58039216, 0.48627451, 0.40392157]],
#
#        [[0.0627451 , 0.07843137, 0.07843137],
#         [0.        , 0.        , 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         ...,
#         [0.48235294, 0.34509804, 0.21568627],
#         [0.46666667, 0.3254902 , 0.19607843],
#         [0.47843137, 0.34117647, 0.22352941]],
#
#        [[0.09803922, 0.09411765, 0.08235294],
#         [0.0627451 , 0.02745098, 0.        ],
#         [0.19215686, 0.10588235, 0.03137255],
#         ...,
#         [0.4627451 , 0.32941176, 0.19607843],
#         [0.47058824, 0.32941176, 0.19607843],
#         [0.42745098, 0.28627451, 0.16470588]],
#
#        ...,
#
#        [[0.81568627, 0.66666667, 0.37647059],
# ...

# %%
model=Sequential()
model.add(Conv2D(128,kernel_size=(5,5),activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=SGD(learning_rate=0.01), metrics=['accuracy'])

model.fit(X_train,y_train,batch_size=32, epochs=100,verbose=1, validation_data=(X_test,y_test))

model.evaluate(X_test,y_test,verbose=1)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 13s 7ms/step - loss: 2.1888 - accuracy: 0.1730 - val_loss: 2.0578 - val_accuracy: 0.2153
# Epoch 2/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.8845 - accuracy: 0.2895 - val_loss: 1.7536 - val_accuracy: 0.3342
# Epoch 3/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.7124 - accuracy: 0.3622 - val_loss: 1.6310 - val_accuracy: 0.3993
# Epoch 4/100
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5699 - accuracy: 0.4192 - val_loss: 1.4775 - val_accuracy: 0.4536
# Epoch 5/100
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.4808 - accuracy: 0.4577 - val_loss: 1.4047 - val_accuracy: 0.4865
# Epoch 6/100
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.4051 - accuracy: 0.4894 - val_loss: 1.3530 - val_accuracy: 0.5053
# Epoch 7/100
# ...

# %% [markdown]
# ### Zadanie dodatkowe:

# %% [markdown]
# Opis zadania:
#
# Fashion MNIST to zbiór danych, który zawiera 70 000 zdjęć przedmiotów z kategorii odzieży, takich jak: bluzy, buty, torebki, spodnie, koszule, sukienki itp. Każde zdjęcie ma rozmiar 28x28 pikseli i jest przedstawione w odcieniach szarości. Celem zadania jest stworzenie sieci konwolucyjnej, która będzie w stanie poprawnie sklasyfikować zdjęcia na 10 różnych kategorii.
#
# Kroki:
#
# * Zaczynając od importowania bibliotek i zbioru danych Fashion MNIST, zastosuj preprocesing danych, aby przystosować je do uczenia maszynowego.
#
# * Zaprojektuj sieć konwolucyjną, składającą się z warstw konwolucyjnych, warstw MaxPooling, warstw Dropout i warstw Fully-Connected.
#
# * Dostosuj hiperparametry sieci, takie jak liczba filtrów, rozmiar jądra, szybkość uczenia i ilość epok.
#
# * Wytrenuj sieć na zbiorze treningowym, a następnie dokonaj ewaluacji na zbiorze testowym, aby oszacować skuteczność sieci.
#
# * Przetestuj sieć na kilku losowych zdjęciach ze zbioru Fashion MNIST, aby sprawdzić, czy sieć jest w stanie poprawnie klasyfikować przedmioty z różnych kategorii odzieży.

# %%
from keras.datasets import fashion_mnist
# example of loading the fashion_mnist dataset
from matplotlib import pyplot

# load dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (X_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (X_test.shape, y_test.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(X_train[i])
# show the figure
pyplot.show()
# Out:
# Train: X=(60000, 28, 28), y=(60000,)
# Test: X=(10000, 28, 28), y=(10000,)

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist
from keras.utils import to_categorical

# Wczytanie danych treningowych i testowych z Fashion MNIST
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Następnie przeprowadzimy preprocess danych:

# %%
# Normalizacja obrazów
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

# Przekształcenie etykiet na one-hot encoding
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# Rozszerzenie wymiarów obrazów dla warstw konwolucyjnych
train_images = np.expand_dims(train_images, axis=-1)
test_images = np.expand_dims(test_images, axis=-1)

# %% [markdown]
# ### Przygotowanie modelu

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

# %%
model=Sequential()
model.add(Conv2D(128,kernel_size=(5,5),activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=SGD(learning_rate=0.01), metrics=['accuracy'])

model.fit(train_images,train_labels,batch_size=32, epochs=40,verbose=1, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/40
# 1875/1875 [==============================] - 11s 5ms/step - loss: 1.3951 - accuracy: 0.4742 - val_loss: 0.8213 - val_accuracy: 0.6959
# Epoch 2/40
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.7951 - accuracy: 0.7013 - val_loss: 0.7153 - val_accuracy: 0.7386
# Epoch 3/40
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.6888 - accuracy: 0.7410 - val_loss: 0.6257 - val_accuracy: 0.7664
# Epoch 4/40
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6377 - accuracy: 0.7623 - val_loss: 0.5986 - val_accuracy: 0.7812
# Epoch 5/40
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5978 - accuracy: 0.7781 - val_loss: 0.5506 - val_accuracy: 0.7998
# Epoch 6/40
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5633 - accuracy: 0.7921 - val_loss: 0.5457 - val_accuracy: 0.8029
# Epoch 7/40
# ...

# %% [markdown]
# ### Zadanie Airline Passengers

# %% [markdown]
# Zbiór danych zwany "Airline Passengers", który jest szeregiem czasowym reprezentującym miesięczną liczbę pasażerów przewoźnika lotniczego od stycznia 1949 do grudnia 1960 roku. Zbiór ten zawiera 144 obserwacje i jest często wykorzystywany do celów analizy i modelowania szeregów czasowych.

# %% [markdown]
# Oto przykładowe zadanie związane z prognozowaniem szeregu czasowego "Airline Passengers" w oparciu o algorytm konwolucji 1-wymiarowej:
#
# * Wczytanie i preprocess danych:
#
# W pierwszym kroku należy wczytać dane szeregu czasowego oraz dokonać preprocess danych, w tym normalizacji wartości szeregu czasowego, podziału na zestawy treningowe i testowe oraz zmniejszenia wymiarowości szeregu czasowego, jeśli jest to wymagane.

# %%
# importowanie potrzebnych bibliotek
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Wczytanie danych
data = pd.read_csv('https://raw.githubusercontent.com/marcin119a/PUMP2/main/flights.csv')
data['date'] =  pd.to_datetime(data['year'].astype(str) + ' ' + data['month'].astype(str), format='%Y %B')

data = data.drop(columns=['month', 'year'])

# Normalizacja danych

data = data.set_index('date')

# Normalizacja danych
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# %%
import numpy as np
import pandas as pd

# Podział danych na zestawy treningowe i testowe
train_size = int(len(data) * 0.7)
train_data, test_data = data[:train_size], data[train_size:]


# Zmniejszenie wymiarowości danych
window_size = 12

def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i+time_steps)])
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)


X_train, y_train = create_dataset(train_data, train_data, window_size)
X_test, y_test = create_dataset(test_data, test_data, window_size)

# %% [markdown]
# Projektowanie i trening modelu:
# * Następnie należy zaprojektować model sieci neuronowej, który będzie w stanie przewidzieć przyszłe wartości szeregu czasowego. W tym przykładzie wykorzystamy model konwolucyjny 1-wymiarowy (1D Convolutional Neural Network).

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from keras.optimizers import Adam

#Todo Model
model=Sequential()
model.add(Conv1D(128,kernel_size=3,activation='relu', input_shape=(window_size,1)))
model.add(MaxPooling1D(pool_size=(2)))

#model.add(Dropout(0.25))
model.add(Flatten())
#model.add(Dense(15, activation='relu'))
model.add(Dense(1))


model.compile(loss='mse', optimizer=Adam(learning_rate=0.01), metrics=['mse'])

model.fit(X_train,y_train,batch_size=5, epochs=10,verbose=1, validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 18/18 [==============================] - 1s 14ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0348 - val_mse: 0.0348
# Epoch 2/10
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0120 - val_mse: 0.0120
# Epoch 3/10
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 4/10
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0122 - val_mse: 0.0122
# Epoch 5/10
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 6/10
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 7/10
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 8/10
# ...

# %%
## todo wizualizacja:
y_pred = model.predict(X_test)

# wizualizacja wyników predykcji
plt.plot(y_test, label='Rzeczywiste wartości')
plt.plot(y_pred, label='Prognozy')
plt.legend()
plt.title('prognoza lotów na zbiorze testowym')
# Out:
# 1/1 [==============================] - 0s 55ms/step
# Text(0.5, 1.0, 'prognoza lotów na zbiorze testowym')
