# %% [markdown]
# <a href="https://colab.research.google.com/github/Nasthl/macnine-learning-/blob/main/%5BCOLAB%5D_Copy_of_puste_UO_Podstawy_uczenia_maszynowego_Zajecia_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


tips = pd.read_csv('https://raw.githubusercontent.com/marcin119a/PODSTAWY-UCZENIA-MASZYNOWEGO-W-PYTHONIE-/main/tips.csv')

# %% [markdown]
# Zbiór danych "tips" to popularny zestaw danych zawarty w bibliotece Seaborn. Zawiera informacje na temat faktur wystawionych w fikcyjnym restauracji. Zbiór składa się z kilku kolumn, które zawierają różne informacje dotyczące poszczególnych rachunków, takie jak:
#
#
# * total_bill: Całkowita kwota rachunku, obejmująca opłatę za posiłek i ewentualne napiwki.
# * tip: Kwota napiwku pozostawiona przez klienta.
# * sex: Płeć osoby płacącej rachunek (mężczyzna lub kobieta).
# * smoker: Czy osoba płacąca rachunek jest paląca (Yes - tak, No - nie).
# * day: Dzień tygodnia, w którym odbył się posiłek.
# * time: Czy posiłek był serwowany w porze lunchu czy kolacji.
# *  size: Liczba osób przy stole.

# %% [markdown]
# ## Zadania Grupowanie
# Oto kilka zadań związanych z zbiorem danych "tips":
#
# 1. Oblicz średnią wartość rachunku dla wszystkich płci.
# 2. Porównaj średnią wartość napiwku dla palących i niepalących gości.
# 3. Sprawdź, który dzień tygodnia jest najbardziej popularny w restauracji na podstawie liczby obsłużonych gości.
# 4. Oblicz procentowy udział płci w całkowitej liczbie gości.
# 5. Znajdź dzień tygodnia, w którym goście zostawiają największe napiwki.
# 6. Porównaj średnią wartość rachunku dla grup o różnej liczbie osób przy stole.
# 7. Oblicz procentowy udział lunchu i kolacji w całkowitej liczbie posiłków.
# 8. Znajdź najczęściej występujący rozmiar grupy.
#
# Te zadania pozwalają na eksplorację i analizę różnych aspektów zbioru danych "tips" i mogą dostarczyć ciekawych wniosków na temat zachowań klientów w restauracji.
#
# W celu rozwiązania tych zadań można użyć różnych funkcji i metod dostępnych w bibliotece pandas, takich jak mean(), max(), min(), groupby(), value_counts(), sum(), oraz dodawanie nowych kolumn poprzez operator.

# %% [markdown]
# Oblicz średnią wartość rachunku dla wszystkich płci:

# %%
tips
# Out:
#      index_of_row  total_bill   tip     sex smoker   day    time  size
# 0               0       16.99  1.01  Female     No   Sun  Dinner     2
# 1               1       10.34  1.66    Male     No   Sun  Dinner     3
# 2               2       21.01  3.50    Male     No   Sun  Dinner     3
# 3               3       23.68  3.31    Male     No   Sun  Dinner     2
# 4               4       24.59  3.61  Female     No   Sun  Dinner     4
# ..            ...         ...   ...     ...    ...   ...     ...   ...
# 239           239       29.03  5.92    Male     No   Sat  Dinner     3
# 240           240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241           241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242           242       17.82  1.75    Male     No   Sat  Dinner     2
# 243           243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
tips.groupby('sex')['total_bill'].mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %% [markdown]
# Porównaj średnią wartość napiwku dla palących i niepalących gości:

# %%
tips.groupby('smoker')['tip'].mean()
# Out:
# smoker
# No     2.991854
# Yes    3.008710
# Name: tip, dtype: float64

# %% [markdown]
# Sprawdź, który dzień tygodnia jest najbardziej popularny w restauracji na podstawie liczby obsłużonych gości:

# %%
tips.groupby('day')['size'].sum().idxmax()
# Out:
# 'Sat'

# %% [markdown]
# Oblicz procentowy udział płci w całkowitej liczbie gości:

# %%
tips['sex'].value_counts(normalize=100)*100
# Out:
# Male      64.344262
# Female    35.655738
# Name: sex, dtype: float64

# %% [markdown]
# Znajdź dzień tygodnia, w którym goście zostawiają największe napiwki:

# %%
tips.groupby('day')['tip'].mean().idxmax()
# Out:
# 'Sun'

# %% [markdown]
# Porównaj średnią wartość rachunku dla grup o różnej liczbie osób przy stole:

# %%
tips.groupby('size')['total_bill'].mean()
# Out:
# size
# 1     7.242500
# 2    16.448013
# 3    23.277632
# 4    28.613514
# 5    30.068000
# 6    34.830000
# Name: total_bill, dtype: float64

# %% [markdown]
# Oblicz procentowy udział lunchu i kolacji w całkowitej liczbie posiłków:

# %%
tips['time'].value_counts(normalize=100)*100
# Out:
# Dinner    0.721311
# Lunch     0.278689
# Name: time, dtype: float64

# %% [markdown]
# Znajdź najczęściej występujący rozmiar grupy:

# %%
tips['size'].mode().values[0]
# Out:
# 2

# %% [markdown]
# Zbior danych dotyczy informacje z różnych krajów, włączając w to dane takie jak:
#
# * Kraj (Country)
# * Produkt krajowy brutto na mieszkańca (GDP per capita)
# * Średnia długość życia (Life expectancy)
# * Populacja (Population)
# * Kontynent (Continent)
#
# Przykład danych dla kraju Lesotho jest następujący:
#
# * Kraj: Lesotho
# * Produkt krajowy brutto na mieszkańca: 2598
# * Średnia długość życia: 47.1
# * Populacja: 2174645
# * Kontynent: Afryka (Africa)

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/marcin119a/PODSTAWY-UCZENIA-MASZYNOWEGO-W-PYTHONIE-/main/income.csv', sep=';')

df.head()
# Out:
#                     Country  GDP per capita  Life expectancy  Population  \
# 0                   Lesotho            2598             47.1     2174645
# 1  Central African Republic             599             49.6     4546100
# 2                 Swaziland            6095             51.8     1319011
# 3               Afghanistan            1925             53.8    33736494
# 4                   Somalia             624             54.2    13908129
#
#   Continent
# 0    Africa
# 1    Africa
# 2    Africa
# 3      Asia
# 4    Africa

# %% [markdown]
# Oto kilka zadań związanych z filtrowaniem danych w bibliotece pandas dla zbioru danych "Country":
#
# 1. Wyświetl informacje tylko o krajach z kontynentu Afryka (Africa).
# 2. Znajdź kraje, w których średnia długość życia przekracza 80 lat.
# 3. Wybierz kraje, których populacja jest większa niż 10 milionów.
# 4. Znajdź kraj o najwyższym dochodzie na mieszkańca.
# 5. Zidentyfikuj kraje, które mają niski dochód na mieszkańca, ale długą średnią długość życia.
# 6. Wybierz kraje, których populacja znajduje się w przedziale od 5 do 10 milionów.
# 7. Znajdź kraje, których dochód na mieszkańca jest poniżej średniej, ale mają wysoką średnią długość życia.
# 8. Wyświetl informacje tylko o krajach o populacji większej niż 1 milion i średniej długości życia większej niż 70 lat.
# 9. Znajdź kraje, które mają wysoki dochód na mieszkańca i niską populację.
# 10. Wybierz kraje, które znajdują się na kontynencie poza Afryką i mają dochód na mieszkańca powyżej 5000.
#
# W celu rozwiązania tych zadań można użyć różnych funkcji i metod dostępnych w bibliotece pandas, takich jak mean(), query(), sum(), oraz dodawanie nowych kolumn poprzez operator [].

# %% [markdown]
# Wyświetl informacje tylko o krajach z kontynentu Afryka (Africa):

# %%
#df[df['Continent']=='Africa']
df.query('Continent == "Africa"')
# Out:
#                       Country  GDP per capita  Life expectancy  Population  \
# 0                     Lesotho            2598             47.1     2174645
# 1    Central African Republic             599             49.6     4546100
# 2                   Swaziland            6095             51.8     1319011
# 4                     Somalia             624             54.2    13908129
# 5               Guinea-Bissau            1386             55.6     1770526
# 6                 South Sudan            3047             56.1    11882136
# 7                      Zambia            4034             56.7    16100587
# 8                  Mozambique            1176             57.1    28010691
# 9                Sierra Leone            2085             57.1     7237025
# 10                       Chad            2191             57.4    14009413
# 11                   Botswana           17196             58.7     2209197
# 12                     Guinea            1225             59.1    12091533
# 13              Cote d'Ivoire            3491             59.1    23108472
# 14                   Zimbabwe            1801             59.3    15777451
# 15                   Cameroon            2897             59.4    22834522
# 16                     Angola            7615             59.6    27859305
# 17                       Mali            1684             60.2    17467905
# 18                     Malawi             799             60.5    17573607
# 19           Congo, Dem. Rep.             809             60.8    76196619
# 20               Burkina Faso            1654             60.9    18110624
# 22                      Niger             943             61.0    19896965
# 23          Equatorial Guinea           31087             61.0     1175389
# 24                     Uganda            1680             61.3    40144870
# 25               South Africa           12509             61.3    55291225
# 26                    Burundi             777             61.4    10199270
# 27                       Togo            1433             61.5     7416802
# 28                Congo, Rep.            6220             61.5     4995648
# 29                      Benin            1830             62.3    10575952
# 31                    Liberia             958             63.2     4499621
# 32                 Madagascar            1400             63.5    24234088
# 33                   Djibouti            3139             63.8      927414
# 35                   Tanzania            2571             64.1    53879957
# 36                    Namibia           10040             64.2     2425561
# 38                    Nigeria            5727             64.6   181181744
# 40                      Kenya            2898             65.1    47236259
# 41                   Ethiopia            1520             65.2    99873033
# 42                    Senegal            2251             65.3    14976994
# 43                      Ghana            4099             65.3    27582821
# 45                     Rwanda            1549             65.9    11629553
# 47                      Gabon           18627             65.9     1930175
# 55                      Sudan            3975             67.5    38647803
# 56      Sao Tome and Principe            3003             68.0      195553
# 58                    Comoros            1472             68.1      777424
# 59                     Gambia            1644             68.1     1977590
# 64                 Mauritania            3877             69.7     4182341
# 76                      Egypt           11031             71.5    93778172
# 96                      Libya           17261             74.1     6234955
# 97                 Seychelles           25684             74.1       93419
# 100                 Mauritius           18350             74.5     1262605
# 102                   Morocco            7319             74.6    34803322
# 124                   Algeria           13434             76.4    39871528
# 134                   Tunisia           11126             77.6    11273661
#
#     Continent
# 0      Africa
# 1      Africa
# 2      Africa
# 4      Africa
# 5      Africa
# 6      Africa
# 7      Africa
# 8      Africa
# 9      Africa
# 10     Africa
# 11     Africa
# 12     Africa
# 13     Africa
# 14     Africa
# 15     Africa
# 16     Africa
# 17     Africa
# 18     Africa
# 19     Africa
# 20     Africa
# 22     Africa
# 23     Africa
# 24     Africa
# 25     Africa
# 26     Africa
# 27     Africa
# 28     Africa
# 29     Africa
# 31     Africa
# 32     Africa
# 33     Africa
# 35     Africa
# 36     Africa
# 38     Africa
# 40     Africa
# 41     Africa
# 42     Africa
# 43     Africa
# 45     Africa
# 47     Africa
# 55     Africa
# 56     Africa
# 58     Africa
# 59     Africa
# 64     Africa
# 76     Africa
# 96     Africa
# 97     Africa
# 100    Africa
# 102    Africa
# 124    Africa
# 134    Africa

# %% [markdown]
# Znajdź kraje, w których średnia długość życia przekracza 80 lat:

# %%
df[df['Life expectancy']>80]
# Out:
#               Country  GDP per capita  Life expectancy  Population  \
# 159        Costa Rica           14132            80.30     4807852
# 160            Kuwait           82633            80.30     3935794
# 161           Denmark           43495            80.40     5683483
# 162           Belgium           41240            80.50    11274196
# 163          Portugal           26437            80.80    10358076
# 164           Germany           44053            80.80    81686611
# 165      Macao, China          148374            80.82      600942
# 166          Slovenia           28550            80.90     2063531
# 167           Finland           38923            80.90     5479531
# 168            Greece           25430            81.00    10820883
# 169       South Korea           34644            81.00    51014947
# 170    United Kingdom           38225            81.00    65128861
# 171           Austria           44401            81.30     8633169
# 172       Netherlands           45784            81.30    16939923
# 173       New Zealand           34186            81.40     4595700
# 174            Canada           43294            81.70    35832513
# 175           Ireland           47758            81.70     4646554
# 176            Cyprus           29797            81.80     1160985
# 177            France           37599            81.80    66624068
# 178            Norway           64304            82.00     5190239
# 179         Singapore           80794            82.00     5535002
# 180             Malta           30265            82.10      431874
# 181            Israel           31590            82.10     8380100
# 182            Sweden           44892            82.10     9799186
# 183             Italy           33297            82.20    60730582
# 184        Luxembourg           88314            82.20      569604
# 185         Australia           44056            82.30    23850784
# 186             Spain           32979            82.60    46444832
# 187       Switzerland           56118            83.00     8282396
# 188             Japan           36162            83.20   127141000
# 189           Iceland           42182            83.30      330815
# 190  Hong Kong, China           53874            83.73     7291300
# 191           Andorra           46577            84.80       78014
#
#          Continent
# 159  North America
# 160           Asia
# 161         Europe
# 162         Europe
# 163         Europe
# 164         Europe
# 165           Asia
# 166         Europe
# 167         Europe
# 168         Europe
# 169           Asia
# 170         Europe
# 171         Europe
# 172         Europe
# 173      Australia
# 174  North America
# 175         Europe
# 176         Europe
# 177         Europe
# 178         Europe
# 179           Asia
# 180         Europe
# 181           Asia
# 182         Europe
# 183         Europe
# 184         Europe
# 185      Australia
# 186         Europe
# 187         Europe
# 188           Asia
# 189         Europe
# 190           Asia
# 191         Europe

# %% [markdown]
# Wybierz kraje, których populacja jest większa niż 10 milionów:

# %%
#df[df['Population']>10000000]
df.query('Population >10000000')
# Out:
#          Country  GDP per capita  Life expectancy  Population  Continent
# 3    Afghanistan            1925             53.8    33736494       Asia
# 4        Somalia             624             54.2    13908129     Africa
# 6    South Sudan            3047             56.1    11882136     Africa
# 7         Zambia            4034             56.7    16100587     Africa
# 8     Mozambique            1176             57.1    28010691     Africa
# ..           ...             ...              ...         ...        ...
# 177       France           37599             81.8    66624068     Europe
# 183        Italy           33297             82.2    60730582     Europe
# 185    Australia           44056             82.3    23850784  Australia
# 186        Spain           32979             82.6    46444832     Europe
# 188        Japan           36162             83.2   127141000       Asia
#
# [88 rows x 5 columns]

# %% [markdown]
# Znajdź kraj o najwyższym dochodzie na mieszkańca:

# %%
df[df['GDP per capita']==df['GDP per capita'].max()]
# Out:
#           Country  GDP per capita  Life expectancy  Population Continent
# 165  Macao, China          148374            80.82      600942      Asia

# %% [markdown]
# Zidentyfikuj kraje, które mają niski dochód na mieszkańca, ale długą średnią długość życia:

# %%
df[(df['GDP per capita']<df['GDP per capita'].quantile(0.4)) & (df['Life expectancy']>df['Life expectancy'].quantile(0.6)) ]
# Out:
#        Country  GDP per capita  Life expectancy  Population      Continent
# 115    Vietnam            5623             75.4    93571567           Asia
# 139  Nicaragua            4712             78.0     6082035  North America

# %% [markdown]
# Wybierz kraje, których populacja znajduje się w przedziale od 5 do 10 milionów:

# %%
df[(df['Population']>=5000000) & (df['Population']<=10000000)]
# Out:
#                   Country  GDP per capita  Life expectancy  Population  \
# 9            Sierra Leone            2085            57.10     7237025
# 21       Papua New Guinea            2529            60.90     7919825
# 27                   Togo            1433            61.50     7416802
# 51                    Lao            5212            67.10     6663967
# 65        Kyrgyz Republic            3245            69.80     5956900
# 66           Turkmenistan           15865            70.00     5565284
# 70                Belarus           17415            71.00     9489616
# 84             Tajikistan            2582            72.40     8548651
# 89             Azerbaijan           16986            72.90     9649341
# 90               Honduras            4270            73.00     8960829
# 96                  Libya           17261            74.10     6234955
# 98               Paraguay            8219            74.40     6639119
# 108              Bulgaria           16371            74.80     7177991
# 109           El Salvador            7776            74.90     6312478
# 117  United Arab Emirates           60749            75.40     9154302
# 122                Serbia           12908            76.20     7095383
# 128               Hungary           24200            76.70     9843028
# 136       Slovak Republic           27204            77.60     5423801
# 139             Nicaragua            4712            78.00     6082035
# 144                Jordan           11752            78.50     9159302
# 149               Lebanon           17050            78.90     5851479
# 161               Denmark           43495            80.40     5683483
# 167               Finland           38923            80.90     5479531
# 171               Austria           44401            81.30     8633169
# 178                Norway           64304            82.00     5190239
# 179             Singapore           80794            82.00     5535002
# 181                Israel           31590            82.10     8380100
# 182                Sweden           44892            82.10     9799186
# 187           Switzerland           56118            83.00     8282396
# 190      Hong Kong, China           53874            83.73     7291300
#
#          Continent
# 9           Africa
# 21       Australia
# 27          Africa
# 51            Asia
# 65            Asia
# 66            Asia
# 70          Europe
# 84            Asia
# 89            Asia
# 90   North America
# 96          Africa
# 98   South America
# 108         Europe
# 109  North America
# 117           Asia
# 122         Europe
# 128         Europe
# 136         Europe
# 139  North America
# 144           Asia
# 149           Asia
# 161         Europe
# 167         Europe
# 171         Europe
# 178         Europe
# 179           Asia
# 181           Asia
# 182         Europe
# 187         Europe
# 190           Asia

# %% [markdown]
# Znajdź kraje, których dochód na mieszkańca jest poniżej średniej, ale mają wysoką średnią długość życia:

# %%
df[(df['GDP per capita']<df['GDP per capita'].mean()) & (df['Life expectancy']>df['Life expectancy'].quantile(0.5)) ]
# Out:
#                     Country  GDP per capita  Life expectancy  Population  \
# 81              North Korea            1390             72.1    25243917
# 83              Timor-Leste            2086             72.4     1240977
# 84               Tajikistan            2582             72.4     8548651
# 86                Guatemala            7279             72.6    16252429
# 87                   Bhutan            7983             72.7      787386
# 88                  Georgia            7474             72.9     3717100
# 89               Azerbaijan           16986             72.9     9649341
# 90                 Honduras            4270             73.0     8960829
# 91                 Dominica           10503             73.1       73162
# 92                    Samoa            5558             73.2      193759
# 93                  Bolivia            6295             73.2    10724705
# 95                  Moldova            4896             73.9     3554108
# 96                    Libya           17261             74.1     6234955
# 98                 Paraguay            8219             74.4     6639119
# 99                   Brazil           15441             74.4   205962108
# 100               Mauritius           18350             74.5     1262605
# 101      West Bank and Gaza            4319             74.6     4422143
# 102                 Morocco            7319             74.6    34803322
# 103                    Iran           15573             74.6    79360487
# 104                 Armenia            7763             74.7     2916950
# 105                Thailand           14512             74.7    68657600
# 106               St. Lucia            9997             74.8      177206
# 107               Venezuela           15753             74.8    31155134
# 108                Bulgaria           16371             74.8     7177991
# 109             El Salvador            7776             74.9     6312478
# 110                 Jamaica            8606             75.0     2871934
# 113      Dominican Republic           12837             75.3    10528394
# 115                 Vietnam            5623             75.4    93571567
# 118                Barbados           12984             75.7      284217
# 120                 Ecuador           10996             75.9    16144368
# 121                  Mexico           16850             75.9   125890949
# 122                  Serbia           12908             76.2     7095383
# 123                   China           13334             76.2  1371220000
# 124                 Algeria           13434             76.4    39871528
# 126          Macedonia, FYR           12547             76.5     2079308
# 127               Argentina           17344             76.5    43417765
# 131              Montenegro           14833             77.2      622159
# 133               Sri Lanka           10624             77.6    20966000
# 134                 Tunisia           11126             77.6    11273661
# 139               Nicaragua            4712             78.0     6082035
# 140                 Albania           10620             78.0     2880703
# 141                Colombia           12761             78.0    48228697
# 144                  Jordan           11752             78.5     9159302
# 148  Bosnia and Herzegovina            9833             78.9     3535961
# 149                 Lebanon           17050             78.9     5851479
# 154                    Peru           11903             79.5    31376671
# 158                Maldives           14408             80.0      418403
# 159              Costa Rica           14132             80.3     4807852
#
#          Continent
# 81            Asia
# 83       Australia
# 84            Asia
# 86   North America
# 87            Asia
# 88            Asia
# 89            Asia
# 90   North America
# 91   North America
# 92       Australia
# 93   South America
# 95          Europe
# 96          Africa
# 98   South America
# 99   South America
# 100         Africa
# 101           Asia
# 102         Africa
# 103           Asia
# 104           Asia
# 105           Asia
# 106  North America
# 107  South America
# 108         Europe
# 109  North America
# 110  North America
# 113  North America
# 115           Asia
# 118  North America
# 120  South America
# 121  North America
# 122         Europe
# 123           Asia
# 124         Africa
# 126         Europe
# 127  South America
# 131         Europe
# 133           Asia
# 134         Africa
# 139  North America
# 140         Europe
# 141  South America
# 144           Asia
# 148         Europe
# 149           Asia
# 154  South America
# 158           Asia
# 159  North America

# %% [markdown]
# Wyświetl informacje tylko o krajach o populacji większej niż 1 milion i średniej długości życia większej niż 70 lat:

# %%
df[(df['Population']>1000000) & (df['Life expectancy']>70)]
# Out:
#               Country  GDP per capita  Life expectancy  Population  Continent
# 67         Kazakhstan           23468            70.20    17544126       Asia
# 68         Bangladesh            3161            70.40   161200886       Asia
# 69        Philippines            6876            71.00   101716359       Asia
# 70            Belarus           17415            71.00     9489616     Europe
# 71             Russia           23038            71.00   144096870     Europe
# ..                ...             ...              ...         ...        ...
# 185         Australia           44056            82.30    23850784  Australia
# 186             Spain           32979            82.60    46444832     Europe
# 187       Switzerland           56118            83.00     8282396     Europe
# 188             Japan           36162            83.20   127141000       Asia
# 190  Hong Kong, China           53874            83.73     7291300       Asia
#
# [101 rows x 5 columns]

# %% [markdown]
# Znajdź kraje, które mają wysoki dochód na mieszkańca i niską populację:

# %%
df[(df['GDP per capita']>df['GDP per capita'].quantile(0.8)) & (df['Population']<df['Population'].quantile(0.2)) ]
# Out:
#                Country  GDP per capita  Life expectancy  Population  \
# 23   Equatorial Guinea           31087            61.00     1175389
# 119              Aruba           37138            75.72      104341
# 130             Brunei           73003            77.10      417542
# 146            Bermuda           47081            78.50       65250
# 165       Macao, China          148374            80.82      600942
# 184         Luxembourg           88314            82.20      569604
# 189            Iceland           42182            83.30      330815
# 191            Andorra           46577            84.80       78014
#
#          Continent
# 23          Africa
# 119  North America
# 130           Asia
# 146  North America
# 165           Asia
# 184         Europe
# 189         Europe
# 191         Europe

# %% [markdown]
# Wybierz kraje, które znajdują się na kontynencie poza Afryką i mają dochód na mieszkańca powyżej 5000:

# %%
df[(df['Continent']!='Africa') & (df['GDP per capita']>5000)]
# Out:
#               Country  GDP per capita  Life expectancy  Population  \
# 44               Fiji            7925            65.80      892149
# 49             Guyana            6816            66.80      768514
# 51                Lao            5212            67.10     6663967
# 52           Mongolia           11819            67.10     2976877
# 53              India            5903            67.20  1309053980
# ..                ...             ...              ...         ...
# 187       Switzerland           56118            83.00     8282396
# 188             Japan           36162            83.20   127141000
# 189           Iceland           42182            83.30      330815
# 190  Hong Kong, China           53874            83.73     7291300
# 191           Andorra           46577            84.80       78014
#
#          Continent
# 44       Australia
# 49   South America
# 51            Asia
# 52            Asia
# 53            Asia
# ..             ...
# 187         Europe
# 188           Asia
# 189         Europe
# 190           Asia
# 191         Europe
#
# [117 rows x 5 columns]

# %% [markdown]
# # Zadanie 3
#
# Jest to popularny zbiór danych zawierający informacje dotyczące pasażerów na statku Titanic, który zatonął w 1912 roku. Zbiór danych "Titanic" zawiera różne kolumny, takie jak:
#
# * Survived: Czy pasażer przeżył (0 - Nie, 1 - Tak)
# * Pclass: Klasa biletu (1 - Pierwsza klasa, 2 - Druga klasa, 3 - Trzecia klasa)
# * Sex: Płeć pasażera
# * Age: Wiek pasażera
# * SibSp: Liczba rodzeństwa/małżonków na pokładzie
# * Parch: Liczba rodziców/dzieci na pokładzie
# * Fare: Opłata za bilet

# %%
import pandas as pd

titanic_df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Oto kilka zadań związanych z grupowaniem, filtrowaniem i operacjami agregującymi na zbiorze danych "Titanic":
#
# 1. Znajdź średni wiek pasażerów na Titaniku.
# 2. Oblicz najwyższą cenę biletu na Titanicu.
# 3. Zgrupuj pasażerów według klasy biletu (Pclass) i oblicz średnią cenę biletu dla każdej klasy.
# 4. Znajdź najmłodszego i najstarszego pasażera na Titaniku.
# 5. Wybierz pasażerów, którzy przetrwali katastrofę (Survived = 1) i mieli wiek poniżej 18 lat.
# 6. Oblicz sumę opłat za bilety dla pasażerów z każdego portu (Embarked).
# 7. Dodaj nową kolumnę o nazwie "FamilySize", która będzie sumą kolumn "SibSp" i "Parch" (liczba rodzeństwa/małżonków oraz liczba rodziców/dzieci).
# 8. Zgrupuj pasażerów według płci (Sex) i oblicz medianę wieku dla każdej płci.
# 9. Wybierz pasażerów, którzy mieli najwyższą opłatę za bilet spośród tych, którzy przeżyli (Survived = 1).
#
# W celu rozwiązania tych zadań można użyć różnych funkcji i metod dostępnych w bibliotece pandas, takich jak mean(), max(), min(), groupby(), filter(), sum(), oraz dodawanie nowych kolumn poprzez operator [] lub funkcję query().

# %% [markdown]
# 1. Znajdź średni wiek pasażerów na Titaniku.

# %%
titanic_df['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# 2. Oblicz najwyższą cenę biletu na Titanicu.

# %%
titanic_df['Fare'].max()
# Out:
# 512.3292

# %% [markdown]
# 3. Zgrupuj pasażerów według klasy biletu (Pclass) i oblicz średnią cenę biletu dla każdej klasy.

# %%
titanic_df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# 4. Znajdź najmłodszego i najstarszego pasażera na Titaniku.

# %%
titanic_df[(titanic_df['Age']==titanic_df['Age'].max()) | (titanic_df['Age']==titanic_df['Age'].min())]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 803          804         1       3       Thomas, Master. Assad Alexander
#
#       Sex    Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 630  male  80.00      0      0  27042  30.0000   A23        S
# 803  male   0.42      0      1   2625   8.5167   NaN        C

# %% [markdown]
# 5. Wybierz pasażerów, którzy przetrwali katastrofę (Survived = 1) i mieli wiek poniżej 18 lat.

# %%
titanic_df[(titanic_df['Survived']==1) & (titanic_df['Age']<18)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 9             10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 830          831         1       3   Yasbeck, Mrs. Antoni (Selini Alexander)
# 831          832         1       2           Richards, Master. George Sibley
# 853          854         1       1                 Lines, Miss. Mary Conover
# 869          870         1       3           Johnson, Master. Harold Theodor
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
#
#         Sex    Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 9    female  14.00      1      0         237736  30.0708   NaN        C
# 10   female   4.00      1      1        PP 9549  16.7000    G6        S
# 22   female  15.00      0      0         330923   8.0292   NaN        Q
# 39   female  14.00      1      0           2651  11.2417   NaN        C
# 43   female   3.00      1      2  SC/Paris 2123  41.5792   NaN        C
# ..      ...    ...    ...    ...            ...      ...   ...      ...
# 830  female  15.00      1      0           2659  14.4542   NaN        C
# 831    male   0.83      1      1          29106  18.7500   NaN        S
# 853  female  16.00      0      1       PC 17592  39.4000   D28        S
# 869    male   4.00      1      1         347742  11.1333   NaN        S
# 875  female  15.00      0      0           2667   7.2250   NaN        C
#
# [61 rows x 12 columns]

# %% [markdown]
# 6. Oblicz sumę opłat za bilety dla pasażerów z każdego portu (Embarked).

# %%
titanic_df.groupby('Embarked')['Fare'].sum()
# Out:
# Embarked
# C    10072.2962
# Q     1022.2543
# S    17439.3988
# Name: Fare, dtype: float64

# %% [markdown]
# 7. Dodaj nową kolumnę o nazwie "FamilySize", która będzie sumą kolumn "SibSp" i "Parch".

# %%
titanic_df['FamilySize']=titanic_df['SibSp']+titanic_df['Parch']
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0        0         A/5 21171   7.2500   NaN        S           1
# 1        0          PC 17599  71.2833   C85        C           1
# 2        0  STON/O2. 3101282   7.9250   NaN        S           0
# 3        0            113803  53.1000  C123        S           1
# 4        0            373450   8.0500   NaN        S           0
# ..     ...               ...      ...   ...      ...         ...
# 886      0            211536  13.0000   NaN        S           0
# 887      0            112053  30.0000   B42        S           0
# 888      2        W./C. 6607  23.4500   NaN        S           3
# 889      0            111369  30.0000  C148        C           0
# 890      0            370376   7.7500   NaN        Q           0
#
# [891 rows x 13 columns]

# %% [markdown]
# 8. Zgrupuj pasażerów według płci (Sex) i oblicz medianę wieku dla każdej płci.

# %%
titanic_df.groupby('Sex')['Age'].median()
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %% [markdown]
# 9. Wybierz pasażerów, którzy mieli najwyższą opłatę za bilet spośród tych, którzy przeżyli (Survived = 1).

# %%
titanic_df[(titanic_df['Survived']==1) & (titanic_df['Fare']>=titanic_df['Fare'].quantile(1))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      FamilySize
# 258           0
# 679           1
# 737           0
